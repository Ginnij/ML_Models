# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv('d:/dataset/ice_creams.csv')
df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature (°C)         49 non-null     float64
#  1   Ice Cream Sales (units)  49 non-null     float64
# dtypes: float64(2)
# memory usage: 916.0 bytes

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,1].values

# %%
X
# Out:
# array([[-4.66226268],
#        [-4.31655945],
#        [-4.21398476],
#        [-3.94966109],
#        [-3.57855372],
#        [-3.4557117 ],
#        [-3.10844012],
#        [-3.08130332],
#        [-2.67246083],
#        [-2.65228679],
#        [-2.65149803],
#        [-2.288264  ],
#        [-2.11186969],
#        [-1.81893761],
#        [-1.66034773],
#        [-1.32637898],
#        [-1.17312327],
#        [-0.77333004],
#        [-0.6737528 ],
#        [-0.14963487],
#        [-0.0361565 ],
#        [-0.03389529],
#        [ 0.0086077 ],
#        [ 0.14924457],
#        [ 0.68878091],
#        [ 0.69359887],
#        [ 0.87490503],
#        [ 1.02418081],
#        [ 1.24071162],
#        [ 1.35981267],
#        [ 1.74000001],
#        [ 1.85055193],
#        [ 1.99931037],
#        [ 2.0751006 ],
#        [ 2.31859124],
#        [ 2.471946  ],
#        [ 2.78483646],
#        [ 2.83176021],
#        [ 2.95993209],
#        [ 3.02087431],
#        [ 3.21136614],
# ...

# %%
y
# Out:
# array([41.84298632, 34.66111954, 39.38300088, 37.53984488, 32.28453119,
#        30.00113848, 22.63540128, 25.36502221, 19.22697005, 20.27967918,
#        13.2758285 , 18.12399121, 11.21829447, 10.01286785, 12.61518115,
#        10.95773134,  6.68912264,  9.39296866,  5.21016262,  4.67364254,
#         0.32862552,  0.89760319,  3.16560001,  1.93141603,  2.57678224,
#         4.62568946,  0.78997365,  2.31380636,  1.29236081,  0.95311531,
#         3.78257014,  4.8579878 ,  8.94382321,  8.17073494,  7.41209403,
#        10.33663062, 15.99661997, 12.56823739, 21.34291574, 20.11441346,
#        22.8394055 , 16.98327874, 25.14208223, 26.10474041, 28.91218793,
#        17.84395652, 34.53074274, 27.69838335, 41.51482194])

# %%
sn.pairplot(df)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=1/5,random_state=0)

# %%
X_train
# Out:
# array([[-2.288264  ],
#        [ 1.85055193],
#        [ 2.0751006 ],
#        [ 1.02418081],
#        [ 4.89903151],
#        [-4.21398476],
#        [ 4.13086796],
#        [-0.6737528 ],
#        [-1.32637898],
#        [ 1.24071162],
#        [ 0.0086077 ],
#        [-1.17312327],
#        [ 3.27004407],
#        [-0.0361565 ],
#        [ 3.31607252],
#        [-2.67246083],
#        [-1.81893761],
#        [ 0.69359887],
#        [-3.4557117 ],
#        [-0.77333004],
#        [ 2.471946  ],
#        [-1.66034773],
#        [ 2.95993209],
#        [-4.31655945],
#        [-2.11186969],
#        [ 3.33593241],
#        [ 0.68878091],
#        [-3.10844012],
#        [ 0.14924457],
#        [ 2.78483646],
#        [-0.03389529],
#        [-0.14963487],
#        [-2.65228679],
#        [ 3.02087431],
#        [ 3.70405744],
#        [-3.94966109],
#        [-4.66226268],
#        [ 4.13353379],
#        [ 3.61077848]])

# %%
y_train
# Out:
# array([18.12399121,  4.8579878 ,  8.17073494,  2.31380636, 41.51482194,
#        39.38300088, 34.53074274,  5.21016262, 10.95773134,  1.29236081,
#         3.16560001,  6.68912264, 16.98327874,  0.32862552, 25.14208223,
#        19.22697005, 10.01286785,  4.62568946, 30.00113848,  9.39296866,
#        10.33663062, 12.61518115, 21.34291574, 34.66111954, 11.21829447,
#        26.10474041,  2.57678224, 22.63540128,  1.93141603, 15.99661997,
#         0.89760319,  4.67364254, 20.27967918, 20.11441346, 17.84395652,
#        37.53984488, 41.84298632, 27.69838335, 28.91218793])

# %%
X_test
# Out:
# array([[ 1.35981267],
#        [-3.57855372],
#        [ 0.87490503],
#        [ 1.74000001],
#        [ 1.99931037],
#        [ 2.83176021],
#        [ 2.31859124],
#        [ 3.21136614],
#        [-3.08130332],
#        [-2.65149803]])

# %%
y_test
# Out:
# array([ 0.95311531, 32.28453119,  0.78997365,  3.78257014,  8.94382321,
#        12.56823739,  7.41209403, 22.8394055 , 25.36502221, 13.2758285 ])

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (39, 1)
# (10, 1)
# (39,)
# (10,)

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_feature=PolynomialFeatures(degree=4)
X_poly=poly_feature.fit_transform(X)
poly_feature.fit(X_poly,y)
lin_reg2=LinearRegression()
lin_reg2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y,color='c')
plt.scatter(X,lin_reg.predict(X),color='b')
plt.title('Truth of Bluff (Linear Regression)')
plt.xlabel('Temperature')
plt.ylabel('Sales')
plt.show()

# %%
plt.scatter(X,y,color='c')
plt.plot(X,lin_reg.predict(X),color='b')
plt.title('Truth of Bluff (Linear Regression)')
plt.xlabel('Temperature')
plt.ylabel('Sales')
plt.show()

# %%
plt.scatter(X,y,color='c')
plt.plot(X,lin_reg2.predict(poly_feature.fit_transform(X)),color='b')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Temperature')
plt.ylabel('Sales')
plt.show()
